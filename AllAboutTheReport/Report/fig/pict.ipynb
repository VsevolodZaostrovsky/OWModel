# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc = {"figure.figsize":(20, 12)})

# %%
n = 20

fruit_names = [str(i * 60) for i in range(1, n + 1)]
fruit_counts = [100/n for i in range(1, n + 1)]

fruit_names1 = [str(i * 60) for i in range(1, n + 1)]
fruit_counts1 = [12.5 if i == 1 or i == n else 75./n for i in range(1, n + 1)]
# fruit_counts1 = [12.5, [1 + " секунда" for i in range(1, n + 1)], 12.5]

fig, ax = plt.subplots(nrows= 2 , ncols= 1)
bar_container = ax[0].bar(fruit_names, fruit_counts)
ax[0].set(ylabel='Доля проданных единиц актива, %', xlabel="Время, секунды", title='TWAP ', ylim=(0, 15))
# ax[0].bar_label(bar_container, fmt='{:,.3f}')

bar_container1 = ax[1].bar(fruit_names1, fruit_counts1)
ax[1].set(ylabel='Доля проданных единиц актива, %', xlabel="Время, секунды", title=r'Оптимальная стратегия Обижаевой-Ванга при $\rho = 0.01$  ', ylim=(0, 15))
# ax[1].bar_label(bar_container1, fmt='{:,.3f}')
plt.savefig("TWAP_OW.pdf")
